# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori,association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data_awal.xls')
data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   Barang 1 Barang 2 Barang 3 Barang 4 Barang 5 Barang 6
# 0     Wine    Chips    Bread   Butter     Milk    Apple
# 1     Wine      NaN    Bread   Butter     Milk      NaN
# 2      NaN      NaN    Bread   Butter     Milk      NaN
# 3      NaN    Chips      NaN      NaN      NaN    Apple
# 4     Wine    Chips    Bread   Butter     Milk    Apple

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Barang 1  36 non-null     object
#  1   Barang 2  36 non-null     object
#  2   Barang 3  40 non-null     object
#  3   Barang 4  39 non-null     object
#  4   Barang 5  45 non-null     object
#  5   Barang 6  43 non-null     object
# dtypes: object(6)
# memory usage: 2.5+ KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Barang 1  36 non-null     object
#  1   Barang 2  36 non-null     object
#  2   Barang 3  40 non-null     object
#  3   Barang 4  39 non-null     object
#  4   Barang 5  45 non-null     object
#  5   Barang 6  43 non-null     object
# dtypes: object(6)
# memory usage: 2.5+ KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Ubah data transaksional menjadi format yang sesuai untuk Apriori
df_encoded = pd.get_dummies(df.apply(lambda x: pd.Series(x.dropna()), axis=1)).astype(bool)

# Terapkan algoritma Apriori untuk menemukan itemset yang sering muncul
frequent_itemsets = apriori(df_encoded, min_support=0.10  , use_colnames=True)


print(frequent_itemsets)
# Out:
#      support                                           itemsets
# 0   0.705882                                    (Barang 1_Wine)
# 1   0.705882                                   (Barang 2_Chips)
# 2   0.784314                                   (Barang 3_Bread)
# 3   0.764706                                  (Barang 4_Butter)
# 4   0.882353                                    (Barang 5_Milk)
# ..       ...                                                ...
# 58  0.333333  (Barang 3_Bread, Barang 6_Apple, Barang 2_Chip...
# 59  0.235294  (Barang 6_Apple, Barang 2_Chips, Barang 5_Milk...
# 60  0.431373  (Barang 3_Bread, Barang 6_Apple, Barang 5_Milk...
# 61  0.333333  (Barang 3_Bread, Barang 6_Apple, Barang 2_Chip...
# 62  0.235294  (Barang 3_Bread, Barang 6_Apple, Barang 2_Chip...
#
# [63 rows x 2 columns]
# ...

# %%
rules = association_rules(frequent_itemsets,metric="lift",min_threshold=1)

list_data = list(frequent_itemsets)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(list_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['support', 'itemsets']

# %%
rules.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        antecedent support  consequent support     support  confidence  \
# count          390.000000          390.000000  390.000000  390.000000
# mean             0.633384            0.633384    0.420814    0.687966
# std              0.166859            0.166859    0.127287    0.183699
# min              0.235294            0.235294    0.235294    0.266667
# 25%              0.509804            0.509804    0.333333    0.541964
# 50%              0.647059            0.647059    0.431373    0.709677
# 75%              0.764706            0.764706    0.509804    0.837838
# ...
